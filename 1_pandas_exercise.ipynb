# %% [markdown]
# <a href="https://colab.research.google.com/github/sayanarajasekhar/pandas/blob/main/1_pandas_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# Please download the dataset from the provided URL. Once downloaded, you can upload it to your Colab environment or Google Drive and then load it into a pandas DataFrame.

# %%
pip install kagglehub[pandas-datasets]

# %% [markdown]
# ### Step 2. Download the dataset

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "en.openfoodfacts.org.products.tsv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "openfoodfacts/world-food-facts",
  file_path
)
# Out:
# /tmp/ipython-input-3799297240.py:8: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# /usr/local/lib/python3.12/dist-packages/kagglehub/pandas_datasets.py:91: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = read_function(

# %% [markdown]
# ### Step 3. Rename the dataframe as food

# %%
food = df

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
# Get dataframe info
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(107), object(56)
# memory usage: 442.8+ MB

# %%
# Get dataframe column details
food.dtypes
# Out:
# code                        object
# url                         object
# creator                     object
# created_t                   object
# created_datetime            object
#                             ...
# carbon-footprint_100g      float64
# nutrition-score-fr_100g    float64
# nutrition-score-uk_100g    float64
# glycemic-index_100g        float64
# water-hardness_100g        float64
# Length: 163, dtype: object

# %%
food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
print(f"Number of shape in dataset (row, col):  {food.shape}")
# Out:
# Number of shape in dataset (row, col):  (356027, 163)

# %%
shape = food.shape
print(f"Number of rows in dataset using shape :  {shape[0]}")
print(f"Number of rows in dataset using len :  {len(food)}")
# Out:
# Number of rows in dataset using shape :  356027
# Number of rows in dataset using len :  356027

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
shape = food.shape
print(f"Number of columns in dataset using shape :  {shape[1]}")
print(f"Number of columns in dataset using len :  {len(food.columns)}")
# Out:
# Number of columns in dataset using shape :  163
# Number of columns in dataset using len :  163

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
print(f"column names in dataset: {food.columns}")
# Out:
# column names in dataset: Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
print(f"105th column names in dataset: {food.columns[104]}")
# Out:
# 105 column names in dataset: -glucose_100g

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
print(f"Type of 105th column: {food.dtypes['-glucose_100g']}")
print(f"Type of 105th column: {food.dtypes[104]}")
# Out:
# Type of 105th column: float64
# Type of 105th column: float64
# /tmp/ipython-input-692593816.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Type of 105th column: {food.dtypes[104]}")

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
print(f"Dataset index : {food.index}")
# Out:
# Dataset index : RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
print(f"Product name of the 19th observation: {food.values[18][7]}")
# Out:
# Product name of the 19th observation: Lotus Organic Brown Jasmine Rice
